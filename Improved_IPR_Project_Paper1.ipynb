# %%
# !pip install rasterio
# !pip install shapely
# !pip install tqdm

import os
import json
import torch
import rasterio
import numpy as np
import pandas as pd  # Added for table creation
from shapely.geometry import shape
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch.nn as nn
import torch.optim as optim
import layers
from functools import partial
import torch.nn.functional as F
from PIL import Image
from tqdm.notebook import tqdm
import shutil
import functools
import warnings
warnings.filterwarnings("ignore")


torch.backends.cudnn.benchmark = True
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (24.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.8.30)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.2.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (2.0.6)
# Requirement already satisfied: numpy<3,>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely) (1.26.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!unzip /content/drive/MyDrive/data/data/train_images1.zip -d /content/drive/MyDrive/data/data

# %%
# !nvidia-smi
# Out:
# Tue Oct 29 01:47:19 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0              46W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
unique_class_labels = {
    11, 12, 13, 15, 17, 18, 19, 20, 21, 23, 24, 25, 26, 27, 28, 29,
    32, 33, 34, 35, 37, 38, 40, 41, 42, 44, 45, 47, 49, 50, 51, 52,
    53, 54, 55, 56, 57, 59, 60, 61, 62, 63, 64, 65, 66, 71, 72, 73,
    74, 75, 76, 77, 79, 82, 83, 84, 86, 89, 91, 93, 94
}

# Map each class label to a sequential index (0 to 60)
class_to_idx = {cls: idx for idx, cls in enumerate(sorted(unique_class_labels))}
idx_to_class = {idx: cls for cls, idx in class_to_idx.items()}
num_classes = len(unique_class_labels)  # Should be 61

# %%
def conv_bn_complex(c_in, c_out, groups=1):
    return nn.Sequential(
        layers.ComplexConvFast(c_in, c_out, kern_size=3,
                               padding=1, groups=groups),
        layers.ComplexBN(c_out),
        nn.ReLU(True),
    )


class residual_complex(nn.Module):
    def __init__(self, c, groups=1):
        super(residual_complex, self).__init__()
        self.res = nn.Sequential(
            conv_bn_complex(c, c, groups=groups),
            conv_bn_complex(c, c, groups=groups)
        )

    def forward(self, x):
        return x + self.res(x)


class flatten(nn.Module):
    def __init__(self):
        super(flatten, self).__init__()

    def forward(self, x):
        return x.view(x.size(0), -1)


class mul(nn.Module):
    def __init__(self, c):
        super(mul, self).__init__()
        self.c = c

    def forward(self, x):
        return x * self.c


def CDS_large(outsize=num_classes, *args, **kwargs):
    channels = {'prep': 64,
                'layer1': 128, 'layer2': 256, 'layer3': 256}
    n = [
        layers.ComplexConvFast(3, channels['prep'], kern_size=3, padding=1, groups=1),

        layers.ConjugateLayer(channels['prep'], kern_size=1, use_one_filter=True),

        conv_bn_complex(channels['prep'], channels['prep'], groups=2),
        conv_bn_complex(channels['prep'], channels['layer1'], groups=2),
        layers.MaxPoolMag(2),
        residual_complex(channels['layer1'], groups=2),
        conv_bn_complex(channels['layer1'], channels['layer2'], groups=4),
        layers.MaxPoolMag(2),
        conv_bn_complex(channels['layer2'], channels['layer3'], groups=2),
        layers.MaxPoolMag(2),
        residual_complex(channels['layer3'], groups=4),
        layers.MaxPoolMag(4),
        flatten(),
        nn.Linear(channels['layer3']*2, outsize, bias=False),
        mul(0.125),
    ]
    return nn.Sequential(*n)

# %%
@functools.lru_cache(maxsize=1024)
def crop_image(image_path, bbox_tuple):
    """
    Crop image using bbox coordinates.
    bbox_tuple must be a tuple (not list) for caching to work.
    """
    with rasterio.open(image_path) as src:
        window = rasterio.windows.Window(
            bbox_tuple[0], bbox_tuple[1],
            bbox_tuple[2] - bbox_tuple[0],
            bbox_tuple[3] - bbox_tuple[1]
        )
        cropped_image = src.read(window=window)
        return np.transpose(cropped_image, (1, 2, 0))

class XViewDataset(Dataset):
    def __init__(self, annotations, image_folder, transform=None):
        self.annotations = annotations
        self.image_folder = image_folder
        self.transform = transform

        # Precompute file paths and verify images exist
        self.valid_annotations = []
        for annotation in annotations:
            image_name = annotation['image_name']
            if not image_name.endswith('.tif'):
                image_name += '.tif'
            image_path = os.path.join(image_folder, image_name)

            if os.path.exists(image_path):
                annotation['image_path'] = image_path
                # Convert bbox to tuple here
                annotation['bbox_tuple'] = tuple(annotation['bbox'])  # Convert list to tuple
                if annotation['type_id'] in class_to_idx:
                    self.valid_annotations.append(annotation)

    def __len__(self):
        return len(self.valid_annotations)

    def __getitem__(self, idx):
        annotation = self.valid_annotations[idx]

        try:
            with rasterio.Env():
                # Use the tuple version of bbox
                cropped_image = crop_image(
                    annotation['image_path'],
                    annotation['bbox_tuple']  # Use tuple instead of list
                )

            if isinstance(cropped_image, np.ndarray):
                cropped_image = Image.fromarray(cropped_image.astype(np.uint8))

            if self.transform:
                cropped_image = self.transform(cropped_image)

            label = class_to_idx[annotation['type_id']]

            return cropped_image, label

        except Exception as e:
            print(f"Error processing image {annotation['image_path']}: {str(e)}")
            # Return a default item instead of None
            return torch.zeros((3, 32, 32)), 0

def parse_geojson(geojson_path):
    with open(geojson_path, 'r') as f:
        geojson_data = json.load(f)

    annotations = []
    for feature in geojson_data['features']:
        properties = feature['properties']
        # Convert bbox to tuple immediately
        bbox = tuple(int(x) for x in properties.get('bounds_imcoords').split(","))
        type_id = properties.get('type_id')
        image_id = properties.get('image_id')

        annotations.append({
            'bbox': bbox,  # Already a tuple
            'type_id': type_id,
            'image_name': image_id
        })

    return annotations

# %%
# Optimized compute_class_priors function
def compute_class_priors(train_loader, num_classes, class_to_idx):
    class_counts = torch.zeros(num_classes)
    total_samples = 0

    # Move to GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    class_counts = class_counts.to(device)

    print("Computing class counts...")
    with torch.no_grad():  # Add this for efficiency
        for _, labels in tqdm(train_loader):
            labels = labels.to(device)
            # Use one-hot encoding for faster counting
            one_hot = torch.zeros(labels.size(0), num_classes, device=device)
            one_hot.scatter_(1, labels.unsqueeze(1), 1)
            class_counts += one_hot.sum(dim=0)
            total_samples += labels.size(0)

    # Add small constant to avoid division by zero and extreme values
    epsilon = 1e-4
    class_counts += epsilon

    # Normalize to get priors
    class_priors = class_counts / total_samples

    return class_priors.cpu().numpy()

def logit_adjustment(logits, class_priors, tau=1.0):
    """
    Improved logit adjustment with temperature scaling and numerical stability
    """
    device = logits.device
    class_priors = torch.tensor(class_priors, device=device, dtype=torch.float32)

    # Add numerical stability
    epsilon = 1e-8
    class_priors = torch.clamp(class_priors, min=epsilon)

    # Temperature scaling for smoother adjustments
    log_priors = torch.log(class_priors) * tau

    # Normalize log_priors to prevent extreme adjustments
    log_priors = (log_priors - log_priors.mean()) / log_priors.std()

    adjusted_logits = logits - log_priors

    return adjusted_logits

# %%
from torch.utils.data.sampler import WeightedRandomSampler

def create_balanced_sampler(train_dataset):
    # Calculate class weights
    labels = [label for _, label in train_dataset]
    class_counts = torch.bincount(torch.tensor(labels))
    total_samples = len(labels)

    class_weights = total_samples / (len(class_counts) * class_counts.float())
    weights = [class_weights[label] for label in labels]

    return WeightedRandomSampler(weights, num_samples=len(weights), replacement=True)

def create_dataloaders(train_annotations, val_annotations, train_dir, val_dir, batch_size=128):
    transform = transforms.Compose([
        transforms.Resize((32, 32)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    train_dataset = XViewDataset(train_annotations, train_dir, transform=transform)
    val_dataset = XViewDataset(val_annotations, val_dir, transform=transform)

    train_sampler = create_balanced_sampler(train_dataset)

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        sampler=train_sampler,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
        prefetch_factor=4,
        drop_last=True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size * 2,
        shuffle=False,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
        prefetch_factor=4
    )

    return train_loader, val_loader

def train_model(model, train_loader, val_loader, num_classes, num_epochs=4, tau=1.0):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Force model to float32 before moving to device
    model = model.float()
    model = model.to(device)

    # Disable mixed precision
    torch.backends.cuda.matmul.allow_tf32 = False
    torch.backends.cudnn.allow_tf32 = False
    torch.backends.cudnn.benchmark = False

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=2e-4, weight_decay=0.01)
    scheduler = optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=2e-4,
        epochs=num_epochs,
        steps_per_epoch=len(train_loader)
    )

    class_priors = compute_class_priors(train_loader, num_classes, class_to_idx)

    best_results = {
        'no_logit': (0, 0),
        'logit': (0, 0)
    }

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        with tqdm(total=len(train_loader), desc=f"Epoch {epoch+1}/{num_epochs}") as pbar:
            for inputs, labels in train_loader:
                # Explicitly convert inputs to float32
                inputs = inputs.to(device).float()
                labels = labels.to(device)

                # Forward pass
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Backward pass
                optimizer.zero_grad(set_to_none=True)
                loss.backward()
                optimizer.step()
                scheduler.step()

                running_loss += loss.item()
                pbar.update(1)
                pbar.set_postfix({"Loss": running_loss / (pbar.n + 1)})

        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / len(train_loader):.4f}')

        if (epoch + 1) % 2 == 0:
            model.eval()
            instance_acc_no_logit, class_acc_no_logit = evaluate_model(
                model, val_loader, num_classes, apply_logit_adjustment=False
            )

            instance_acc_logit, class_acc_logit = evaluate_model(
                model, val_loader, num_classes, apply_logit_adjustment=True, tau=tau
            )

            if instance_acc_no_logit > best_results['no_logit'][0]:
                best_results['no_logit'] = (instance_acc_no_logit, class_acc_no_logit)

            if instance_acc_logit > best_results['logit'][0]:
                best_results['logit'] = (instance_acc_logit, class_acc_logit)

    return best_results


def evaluate_model(model, val_loader, num_classes, class_priors=None, apply_logit_adjustment=True, tau=0.5):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()

    class_correct = torch.zeros(num_classes, device=device)
    class_total = torch.zeros(num_classes, device=device)
    total_correct = 0
    total_samples = 0

    # Create progress bar
    with tqdm(total=len(val_loader), desc="Validating") as pbar:
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)

                if apply_logit_adjustment and class_priors is not None:
                    outputs = logit_adjustment(outputs, class_priors, tau)

                _, predicted = outputs.max(1)

                total_samples += labels.size(0)
                total_correct += (predicted == labels).sum().item()

                # Per-class accuracy
                for cls_idx in range(num_classes):
                    mask = labels == cls_idx
                    if mask.any():
                        class_correct[cls_idx] += (predicted[mask] == labels[mask]).sum()
                        class_total[cls_idx] += mask.sum()

                # Update progress bar
                pbar.update(1)
                pbar.set_postfix({
                    "Acc": total_correct / total_samples
                })

    # Calculate accuracies
    instance_accuracy = total_correct / total_samples

    # Avoid division by zero
    class_total = torch.clamp(class_total, min=1)
    class_accuracies = (class_correct / class_total).cpu().numpy()

    # Print per-class accuracies with actual type_ids
    print("\nPer-class accuracies:")
    for idx, acc in enumerate(class_accuracies):
        actual_type_id = idx_to_class[idx]
        print(f"Type ID {actual_type_id}: {acc:.4f}")

    mean_class_accuracy = class_accuracies.mean()

    # Print summary statistics
    print("\nSummary:")
    print(f"Instance-wise Accuracy: {instance_accuracy:.4f}")
    print(f"Mean Class-wise Accuracy: {mean_class_accuracy:.4f}")

    return instance_accuracy, mean_class_accuracy

# %%
#!unzip /content/drive/MyDrive/data/data/train_images1.zip -d /content/drive/MyDrive/data/data
# Out:
# Archive:  /content/drive/MyDrive/data/data/train_images1.zip
#    creating: /content/drive/MyDrive/data/data/train_images1/
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/._train_images1
#   inflating: /content/drive/MyDrive/data/data/train_images1/462.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._462.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/310.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._310.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/106.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._106.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/112.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._112.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/674.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._674.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/884.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._884.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/847.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._847.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/517.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._517.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/885.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._885.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/107.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._107.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/488.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._488.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/311.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._311.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/463.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._463.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/307.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._307.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/111.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._111.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/105.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._105.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/893.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._893.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/887.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._887.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/38.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._38.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/10.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._10.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/529.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._529.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/500.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._500.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/716.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._716.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/886.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._886.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/892.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._892.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/104.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._104.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/110.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._110.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/474.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._474.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/302.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._302.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/464.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._464.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/128.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._128.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/672.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._672.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/100.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._100.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/712.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._712.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/538.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._538.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/510.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._510.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/289.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._289.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/883.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._883.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/129.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._129.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/303.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._303.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/465.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._465.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/317.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._317.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/315.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._315.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/473.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._473.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/498.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._498.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/659.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._659.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/895.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._895.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/665.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._665.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/671.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._671.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/711.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._711.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/513.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._513.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/506.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._506.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/512.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._512.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/670.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._670.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/102.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._102.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/894.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._894.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/880.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._880.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/658.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._658.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/401.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._401.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/373.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._373.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/415.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._415.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/617.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._617.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/159.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._159.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/777.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._777.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/763.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._763.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/788.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._788.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/575.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._575.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/561.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._561.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/548.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._548.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/574.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._574.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/825.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._825.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/819.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._819.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/158.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._158.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/399.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._399.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/372.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._372.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/414.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._414.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/370.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._370.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/614.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._614.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/600.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._600.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/73.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._73.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/760.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._760.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/774.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._774.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/562.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._562.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/238.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._238.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/563.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._563.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/761.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._761.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/72.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._72.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/8.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._8.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/629.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._629.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/99.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._99.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/601.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._601.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/615.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._615.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/371.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._371.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/375.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._375.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/407.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._407.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/639.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._639.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/89.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._89.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/611.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._611.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/163.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._163.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/605.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._605.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/836.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._836.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/822.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._822.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/765.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._765.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/567.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._567.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/598.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._598.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/764.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._764.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/837.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._837.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/604.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._604.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/610.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._610.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/88.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._88.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/360.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._360.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/374.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._374.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/362.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._362.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/389.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._389.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/606.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._606.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/612.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._612.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/75.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._75.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/772.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._772.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/766.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._766.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/216.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._216.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/203.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._203.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/217.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._217.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/559.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._559.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/767.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._767.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/74.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._74.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/613.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._613.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/149.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._149.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/377.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._377.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/434.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._434.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/144.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._144.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/622.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._622.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/86.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._86.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/92.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._92.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/79.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._79.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/193.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._193.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/805.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._805.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/756.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._756.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/742.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._742.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/781.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._781.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/540.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._540.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/568.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._568.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/596.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._596.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/569.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._569.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/541.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._541.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/794.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._794.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/838.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._838.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/87.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._87.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/637.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._637.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/145.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._145.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/437.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._437.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/345.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._345.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/423.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._423.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/379.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._379.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/386.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._386.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/635.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._635.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/621.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._621.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/609.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._609.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/91.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._91.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/46.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._46.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/741.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._741.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/769.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._769.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/557.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._557.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/580.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._580.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/594.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._594.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/595.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._595.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/556.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._556.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/768.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._768.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/740.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._740.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/47.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._47.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/807.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._807.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/53.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._53.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/813.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._813.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/84.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._84.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/90.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._90.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/608.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._608.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/620.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._620.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/393.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._393.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/378.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._378.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/422.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._422.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/432.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._432.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/340.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._340.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/94.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._94.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/80.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._80.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/618.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._618.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/142.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._142.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/817.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._817.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/5.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._5.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/43.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._43.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/181.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._181.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/744.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._744.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/546.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._546.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/552.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._552.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/584.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._584.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/792.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._792.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/180.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._180.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/42.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._42.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/802.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._802.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/157.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._157.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/619.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._619.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/95.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._95.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/382.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._382.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/355.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._355.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/433.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._433.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/343.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._343.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/380.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._380.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/394.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._394.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/83.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._83.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/97.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._97.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/627.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._627.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/40.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._40.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/814.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._814.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/579.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._579.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/237.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._237.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/223.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._223.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/587.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._587.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/593.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._593.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/791.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._791.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/752.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._752.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/69.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._69.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/815.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._815.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/41.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._41.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/626.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._626.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/140.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._140.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/381.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._381.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/430.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._430.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/342.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._342.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/418.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._418.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/325.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._325.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/457.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._457.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/331.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._331.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/494.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._494.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/641.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._641.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/669.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._669.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/682.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._682.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/735.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._735.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/709.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._709.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/537.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._537.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/523.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._523.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/287.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._287.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/293.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._293.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/708.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._708.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/720.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._720.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/734.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._734.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/33.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._33.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/126.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._126.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/481.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._481.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/324.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._324.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/130.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._130.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/124.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._124.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/118.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._118.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/859.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._859.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/871.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._871.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/31.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._31.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/520.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._520.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/534.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._534.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/252.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._252.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/285.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._285.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/291.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._291.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/509.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._509.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/535.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._535.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/521.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._521.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/24.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._24.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/870.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._870.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/18.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._18.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/680.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._680.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/694.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._694.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/125.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._125.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/131.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._131.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/469.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._469.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/333.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._333.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/455.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._455.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/451.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._451.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/323.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._323.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/445.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._445.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/492.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._492.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/486.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._486.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/109.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._109.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/647.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._647.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/860.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._860.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/20.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._20.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/684.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._684.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/727.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._727.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/525.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._525.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/531.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._531.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/294.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._294.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/295.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._295.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/732.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._732.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/652.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._652.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/493.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._493.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/322.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._322.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/320.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._320.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/650.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._650.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/888.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._888.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/136.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._136.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/863.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._863.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/724.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._724.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/532.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._532.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/254.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._254.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/283.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._283.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/282.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._282.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/296.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._296.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/692.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._692.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/862.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._862.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/889.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._889.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/484.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._484.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/321.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._321.tif
#   inflating: /content/drive/MyDrive/data/data/train_images1/309.tif
#   inflating: /content/drive/MyDrive/data/data/__MACOSX/train_images1/._309.tif

# %%
def main():
    # Paths to your data
    train_geojson_path = '/content/drive/MyDrive/data/data/xview_filtered1.geojson'
    train_dir = '/content/drive/MyDrive/data/data/train_images1'
    val_dir = '/content/drive/MyDrive/data/data/validation_images'

    # Parse the geojson file
    annotations = parse_geojson(train_geojson_path)
    print(f"Initial total annotations: {len(annotations)}")

    # Group annotations by unique image names and verify image existence
    image_to_annotations = {}
    valid_images = []

    for annotation in annotations:
        image_name = annotation['image_name']
        if not image_name.endswith('.tif'):
            image_name += '.tif'

        # Check if image exists in either train or val directory
        train_path = os.path.join(train_dir, image_name)
        val_path = os.path.join(val_dir, image_name)

        if os.path.exists(train_path) or os.path.exists(val_path):
            if image_name not in image_to_annotations:
                image_to_annotations[image_name] = []
                valid_images.append(image_name)
            image_to_annotations[image_name].append(annotation)

    # Get list of valid unique images
    unique_images = valid_images
    print(f"Total valid unique images: {len(unique_images)}")

    # Split the valid unique images into 90% train, 10% validation
    split_ratio = 0.9
    split_idx = int(len(unique_images) * split_ratio)
    train_images = unique_images[:split_idx]
    val_images = unique_images[split_idx:]

    print(f"Training images: {len(train_images)}")
    print(f"Validation images: {len(val_images)}")

    # Assign annotations to training and validation sets based on image names
    train_annotations = []
    val_annotations = []

    for image in train_images:
        train_annotations.extend(image_to_annotations[image])
    for image in val_images:
        val_annotations.extend(image_to_annotations[image])

    print(f"Valid training annotations: {len(train_annotations)}")
    print(f"Valid validation annotations: {len(val_annotations)}")

    # Create validation directory if it doesn't exist
    os.makedirs(val_dir, exist_ok=True)

    # Move the validation images to the validation directory
    moved_images = []
    for image_name in val_images:
        src_path = os.path.join(train_dir, image_name)
        dest_path = os.path.join(val_dir, image_name)

        if os.path.exists(src_path):
            shutil.move(src_path, dest_path)
            moved_images.append(image_name)
            print(f"Moved: {image_name}")

    print(f"Successfully moved {len(moved_images)} validation images")

    # Create dataloaders with only valid annotations
    train_loader, val_loader = create_dataloaders(train_annotations, val_annotations, train_dir, val_dir)

    # Train CDS model
    print("\nTraining CDS model...")
    cds_model = CDS_large()
    cds_results = train_model(cds_model, train_loader, val_loader, num_classes, num_epochs=4, tau=1.0)

    print("\nTraining ResNet18 model...")
    resnet_model = models.resnet18(pretrained=True)
    resnet_model.fc = nn.Linear(resnet_model.fc.in_features, num_classes)
    # Force model to float32 before training
    resnet_model = resnet_model.float()
    resnet_results = train_model(resnet_model, train_loader, val_loader, num_classes, num_epochs=4, tau=1.0)


    # Create results table
    results = pd.DataFrame({
        'Model': ['CDS', 'ResNet18'],
        'Instance-wise Accuracy (No Logit)': [cds_results['no_logit'][0], resnet_results['no_logit'][0]],
        'Class-wise Accuracy (No Logit)': [cds_results['no_logit'][1], resnet_results['no_logit'][1]],
        'Instance-wise Accuracy (Logit Adjusted)': [cds_results['logit'][0], resnet_results['logit'][0]],
        'Class-wise Accuracy (Logit Adjusted)': [cds_results['logit'][1], resnet_results['logit'][1]]
    })

    # Print the results table
    print("\nResults Comparison Table:")
    print(results)

    # Save results
    results.to_csv('model_comparison_results.csv')

if __name__ == '__main__':
    main()
# Out:
# Initial total annotations: 159275
# Total valid unique images: 307
# Training images: 276
# Validation images: 31
# Valid training annotations: 127570
# Valid validation annotations: 31705
# Moved: 111.tif
# Moved: 112.tif
# Moved: 129.tif
# Moved: 130.tif
# Moved: 131.tif
# Moved: 145.tif
# Moved: 157.tif
# Moved: 158.tif
# Moved: 33.tif
# Moved: 40.tif
# Moved: 41.tif
# Moved: 107.tif
# Moved: 109.tif
# Moved: 110.tif
# Moved: 124.tif
# Moved: 126.tif
# Moved: 128.tif
# Moved: 144.tif
# Moved: 149.tif
# Moved: 159.tif
# Moved: 163.tif
# Moved: 481.tif
# Moved: 331.tif
# Moved: 333.tif
# Moved: 340.tif
# Moved: 342.tif
# Moved: 345.tif
# Moved: 370.tif
# Moved: 371.tif
# Moved: 386.tif
# Moved: 389.tif
# Successfully moved 31 validation images
